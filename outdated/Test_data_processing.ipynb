# %%
import numpy as np
import pandas as pd

path = '/Users/kdreyer/Documents/Github/COVID_Dx_GAMES/'
fname_data1 = 'PROCESSED DATA EXP.pkl'
fname_err1 = 'PROCESSED DATA ERR.pkl'
exp_data1 = pd.read_pickle(path + fname_data1)
exp_err1 = pd.read_pickle(path + fname_err1)
# exp_data1
exp_data1.iloc[:, 80:85]
# Out:
#                  Unnamed: 27                      AVERAGE  \
# 2   [1.0, 0.5, 0.001, 0, 90]  [20.0, 10.0, 0.02, 10, 4.5]
# 3                   0.013689                     0.013689
# 4                   0.015874                     0.016708
# 5                   0.017168                     0.017744
# 6                   0.019354                     0.018721
# ..                       ...                          ...
# 59                  0.060248                      0.03589
# 60                  0.061082                     0.035228
# 61                  0.060794                     0.036062
# 62                  0.060622                     0.036034
# 63                  0.061715                     0.036436
#
#                       Unnamed: 2                    Unnamed: 3  \
# 2   [20.0, 10.0, 0.005, 10, 4.5]  [20.0, 10.0, 0.001, 10, 4.5]
# 3                       0.014983                      0.015616
# 4                        0.01737                      0.018031
# ...

# %%
fname_data2 = 'PROCESSED_DATA_rep1_fix_EXP.pkl'
fname_err2 = 'PROCESSED_DATA_rep1_fix_ERR.pkl'
exp_data2 = pd.read_pickle(path + fname_data2)
exp_err2 = pd.read_pickle(path + fname_err2)
exp_data2
exp_data2.iloc[:, 80:85]
# Out:
#                   Unnamed: 27                     AVERAGE  \
# 0   [1.0, 0.5, 0.001, 10, 90]  [20.0, 10.0, 0.02, 0, 4.5]
# 1                    0.010755                    0.013689
# 2                     0.01251                    0.016708
# 3                    0.013689                    0.017744
# 4                    0.014695                    0.018721
# ..                        ...                         ...
# 57                   0.075806                     0.03589
# 58                   0.076669                    0.035228
# 59                   0.076956                    0.036062
# 60                    0.07756                    0.036034
# 61                   0.077675                    0.036436
#
#                      Unnamed: 2                   Unnamed: 3  \
# 0   [20.0, 10.0, 0.005, 0, 4.5]  [20.0, 10.0, 0.001, 0, 4.5]
# 1                      0.014983                     0.015616
# 2                       0.01737                     0.018031
# ...

# %%
print(len(np.linspace(0, 240, 61)))
# Out:
# 61

# %%
fname_data3 = 'PROCESSED_DATA_rep2_EXP.pkl'
fname_err3 = 'PROCESSED_DATA_rep2_ERR.pkl'
exp_data3 = pd.read_pickle(path + fname_data3)
exp_err3 = pd.read_pickle(path + fname_err3)
display(exp_data3)
# Out:
#                       AVERAGE                  Unnamed: 2  \
# 0   [20.0, 10.0, 0.02, 0, 90]  [20.0, 10.0, 0.005, 0, 90]
# 1                    0.070599                    0.072744
# 2                    0.077391                    0.080071
# 3                    0.083467                     0.08454
# 4                    0.087757                    0.088472
# ..                        ...                         ...
# 57                   0.181055                    0.215728
# 58                   0.186059                    0.216801
# 59                   0.187489                    0.220018
# 60                   0.187846                    0.222341
# 61                   0.191957                    0.224665
#
#                     Unnamed: 3                Unnamed: 4  \
# 0   [20.0, 10.0, 0.001, 0, 90]  [20.0, 2.5, 0.02, 0, 90]
# 1                     0.078463                   0.06613
# 2                     0.087221                  0.075961
# ...
